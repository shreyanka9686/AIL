# %%
import matplotlib.pyplot as plt 
import numpy as np 
xpoints=np.array([25,30])
ypoints=np.array([25,200])
plt.plot(ypoints,xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
cpoints=np.array([200,3])
lpoints=np.array([50,80])
plt.plot(cpoints,lpoints)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
xpoints=np.array([8,10])
ypoints=np.array([4,12])
plt.plot(xpoints,ypoints,'*')
plt.show()

# %%
import matplotlib.pylab as plt 
import numpy as np 
xpoints=([2,5,3,8])
ypoints=([6,0,2,6])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ypoints=np.array([8,4,9,10])
plt.plot(ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
xpoints=np.array([4,5,6,8])
plt.plot(xpoints,marker='D')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
xpoints=np.array([4,2,6,14])
plt.plot(xpoints, '*-.k')
plt.show()

# %%
import matplotlib.pylab as plt 
import numpy as np 
ypoints=np.array([12,45,67])
xpoints=np.array([43,56,78])
plt.plot(ypoints,xpoints, marker='^', ms=10)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ypoint=np.array([35,45,56])
plt.plot(ypoints,marker='>',ms=10,mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ypoint=np.array([57,83,23,45])
xpoint=np.array([34,56,77,54])
plt.plot(ypoints,xpoints,marker='^',ms=15,mec='r',mfc='g')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ypoint=np.array([57,83,23,45])
xpoint=np.array([34,56,77,54])
plt.plot(ypoints,xpoints,marker='^',ms=15,mec='r',mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
ypoints=np.array([20,30,34,56])
plt.plot(ypoints,linestyle='-',marker='o',ms='10',mec='b',mfc='hotpink',color='k',linewidth='5')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
y1=np.array([20,30,5,50])
y2=np.array([10,20,60,40])
plt.plot(y1,marker='*',mec='b',ms=10)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x=np.array([10,20,30,40,50,60])
y=np.array([30,20,10,20,50,10])
plt.xlabel("Average Pluse")
plt.ylabel("Calarie Burnage")
plt.plot(x,marker='^',c='g',mec='y')
plt.plot(y,marker='*',c='k',mec='hotpink')
plt.show()

# %%
import matplotlib.pylab as plt 
import numpy as np 
x=np.array([80,56,45,23,78,45,23])
y=np.array([45,78,90,34,56,67,89])
plt.plot(x,y,marker='^',ms=15,mec='y',linewidth='10')
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x=np.array([20,30,10,30,40])
y=np.array([40,20,10,30,40])
font1={'family':'serif','color':'blue','size':15}
font2={'family':'serif','color':'darkred','size':10}
plt.title("Sports Watch Data",loc='left', fontdict=font1)
plt.xlabel("Average Pluse",fontdict=font2)
plt.ylabel("Calaries Burnage",fontdict=font2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x=np.array([20,30,10,30,40])
y=np.array([40,20,10,30,40])
font1={'family':'serif','color':'blue','size':15}
font2={'family':'serif','color':'darkred','size':10}
plt.title("Sports Watch Data",loc='left', fontdict=font1)
plt.xlabel("Average Pluse",fontdict=font2)
plt.ylabel("Calaries Burnage",fontdict=font2)
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x=np.array([20,30,10,30,40])
y=np.array([40,20,10,30,40])
font1={'family':'serif','color':'blue','size':15}
font2={'family':'serif','color':'darkred','size':10}
plt.title("Sports Watch Data",loc='left', fontdict=font1)
plt.xlabel("Average Pluse",fontdict=font2)
plt.ylabel("Calaries Burnage",fontdict=font2)
plt.plot(x,y)
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np 
x=np.array([20,30,10,30,40])
y=np.array([40,20,10,30,40])
font1={'family':'serif','color':'blue','size':15}
font2={'family':'serif','color':'darkred','size':10}
plt.title("Sports Watch Data",loc='left', fontdict=font1)
plt.xlabel("Average Pluse",fontdict=font2)
plt.ylabel("Calaries Burnage",fontdict=font2)
plt.plot(x,y)
plt.grid(color='g',linestyle='--',linewidth=0.5)
plt.show()

# %%
import matplotlib.pylab as plt 
import numpy as np 
x=np.array([10,20,30,40,20])
y=np.array([50,20,30,19,30])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([10,20,30,23])
y=np.array([30,20,12,34])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pylab as plt 
import numpy as np 
x=np.array([10,20,30,40,20])
y=np.array([50,20,30,19,30])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([10,20,30,23])
y=np.array([30,20,12,34])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pylab as plt 
import numpy as np 

x=np.array([10,20,30,40,20])
y=np.array([50,20,30,19,30])

plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([10,20,30,23])
y=np.array([30,20,12,34])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([0, 1, 2, 3])
y=np.array([10, 20, 30, 40])
plt.subplot(2,3,3)

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Title

# %% [markdown]
# You can add a title to each plot with the title() function:

# %% [markdown]
# #### Example
# 2 plots, with titles:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# # Super Title
# You can add a title to the entire figure with the suptitle() function:

# %% [markdown]
# #### Example
# Add a title for the entire figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %% [markdown]
# ## Creating Scatter Plots
# With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %% [markdown]
# #### Example
# A simple scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# The observation in the example above is the result of 13 cars passing by.
#
# The X-axis shows how old the car is.
#
# The Y-axis shows the speed of the car when it passes.
#
# Are there any relationships between the observations?
#
# It seems that the newer the car, the faster it drives, but that could be a coincidence, after all we only registered 13 cars.

# %% [markdown]
# ## Compare Plots
# In the example above, there seems to be a relationship between speed and age, but what if we plot the observations from another day as well? Will the scatter plot tell us something else?

# %% [markdown]
# #### Example
# Draw two plots on the same figure:

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ### Note: The two plots are plotted with two different colors, by default blue and orange, you will learn how to change colors later in this chapter.
#
# By comparing the two plots, I think it is safe to say that they both gives us the same conclusion: the newer the car, the faster it drives.

# %% [markdown]
# # Colors
# You can set your own color for each scatter plot with the color or the c argument:

# %% [markdown]
# #### Example
# Set your own color of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ## Color Each Dot
# You can even set a specific color for each dot by using an array of colors as value for the c argument:

# %% [markdown]
# #### Example
# Set your own color of the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ## ColorMap
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.

# %% [markdown]
# ### How to Use the ColorMap
# You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %% [markdown]
# #### Example
# Create a color array, and specify a colormap in the scatter plot:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# You can include the colormap in the drawing by including the plt.colorbar() statement:

# %% [markdown]
# #### Example
# Include the actual colormap:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ## Available ColorMaps
# You can choose any of the built-in colormaps:

# %% [markdown]
# ### Size
# You can change the size of the dots with the s argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:

# %% [markdown]
# #### Example
# Set your own size for the markers:

# %% [markdown]
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
# y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
# sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
#
# plt.scatter(x, y, s=sizes)
#
# plt.show()

# %% [markdown]
# # Alpha
# You can adjust the transparency of the dots with the alpha argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis

# %% [markdown]
# #### Example
# Set your own size for the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# # Combine Color Size and Alpha
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:

# %% [markdown]
# #### Example
# Create random arrays with 100 values for x-points, y-points, colors and sizes:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()
