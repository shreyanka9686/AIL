# %%
pip install functool
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018207E13680>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/functool/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018207FE78F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/functool/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018207FDA270>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/functool/
# ...

# %%
pip install functool
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement functool (from versions: none)
# ERROR: No matching distribution found for functool

# %%
import functool fr
