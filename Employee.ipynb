# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
data={
    'EName':['Raj','Ram','Rahim','Roja'], 
    'Type':['Adhoc','Regulor','Contract','Regulor'], 
    'Depatment':['CS','EC','EC','CS'], 
    'Experience':[2,8,5,10], 
    'Salary':[10000,20000,5000,15000]
}
df=pd.DataFrame(data) 
df
# Out:
#    EName      Type Depatment  Experience  Salary
# 0    Raj     Adhoc        CS           2   10000
# 1    Ram   Regulor        EC           8   20000
# 2  Rahim  Contract        EC           5    5000
# 3   Roja   Regulor        CS          10   15000

# %%
df['Qualification']=df[['Experience','Salary']].sum()
df
# Out:
#    EName       Type Depatment  Experience  Salary  Qualification
# 0    Raj  irRegulor        CS           2   10000            NaN
# 1    Ram      Adhoc        EC           8   20000            NaN
# 2  Rahim   Contract        EC           5    5000            NaN
# 3   Roja    Regular        CS          10   15000            NaN

# %%
a=df['Type'].value_counts().plot(kind='bar')
a
# Out:
# <Axes: xlabel='Type'>

# %%
plt.bar(df['EName'],df['Type'])
plt.show()
