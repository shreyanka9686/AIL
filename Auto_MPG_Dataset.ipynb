# %% [markdown]
# # Perform the following operation on Autompg.csv of XYZ customer using pandas as

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sn

# %% [markdown]
# # Read data from an existing file

# %%
df=pd.read_csv("C:/Users/ADMIN/Downloads/auto-mpg.csv")
df=pd.DataFrame(df)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
print("Statistical summary of the dataset:")
df.describe()
# Out:
# Statistical summary of the dataset:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# # XYZ custom cars want the data sorted according to the number of cylinders..00

# %%
df.sort_values(by = 'cylinders')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 111  18.0          3          70.0         90    2124          13.5
# 71   19.0          3          70.0         97    2330          13.5
# 334  23.7          3          70.0        100    2420          12.5
# 243  21.5          3          80.0        110    2720          13.5
# 267  27.5          4         134.0         95    2560          14.2
# ..    ...        ...           ...        ...     ...           ...
# 86   14.0          8         304.0        150    3672          11.5
# 285  17.0          8         305.0        130    3840          15.4
# 286  17.6          8         302.0        129    3725          13.4
# 92   13.0          8         351.0        158    4363          13.0
# 0    18.0          8         307.0        130    3504          12.0
#
#      model year  origin                   car name
# 111          73       3                  maxda rx3
# ...

# %%
per_year=df['model year'].value_counts().sort_index()
print("Cars manufactured each year:")
per_year
# Out:
# Cars manufactured each year:
# model year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: count, dtype: int64

# %%
per_year.plot(kind='bar',title='Cars Manufactured Each Year',xlabel='Model year',ylabel='Numbers of Cars')
mp.show()

# %%
s=df[df['cylinders']==8]['car name']
print(s)
# Out:
# 0                 chevrolet chevelle malibu
# 1                         buick skylark 320
# 2                        plymouth satellite
# 3                             amc rebel sst
# 4                               ford torino
#                        ...
# 291           chevrolet malibu classic (sw)
# 292    chrysler lebaron town @ country (sw)
# 298                       cadillac eldorado
# 300       oldsmobile cutlass salon brougham
# 364                   oldsmobile cutlass ls
# Name: car name, Length: 103, dtype: object

# %%
group=df.groupby('car name')['model year'].value_counts()
print(df['model year'].value_counts().sort_index())
print(group)
# Out:
# model year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: count, dtype: int64
# car name                 model year
# amc ambassador brougham  73            1
# amc ambassador dpl       70            1
# amc ambassador sst       72            1
# amc concord              78            1
#                          80            1
#                                       ..
# vw pickup                82            1
# vw rabbit                76            1
#                          80            1
# vw rabbit c (diesel)     80            1
# vw rabbit custom         79            1
# Name: count, Length: 396, dtype: int64

# %%
df['acceleration'].std()
# Out:
# 2.7576889298126757
