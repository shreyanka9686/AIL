# %% [markdown]
# ## A) Consider titanic dataset & handle the missing values using different methods

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
df= pd.read_csv('C:/Users/ADMIN/Downloads/titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892       0.0       3
# 1          893       NaN       3
# 2          894       0.0       2
# 3          895       0.0       3
# 4          896       1.0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         3
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
mean=df['Survived'].mean()
df['Survived'].fillna(mean)
df['Survived']
# Out:
# 0      0.0
# 1      NaN
# 2      0.0
# 3      0.0
# 4      1.0
#       ...
# 413    0.0
# 414    1.0
# 415    0.0
# 416    0.0
# 417    0.0
# Name: Survived, Length: 418, dtype: float64

# %%
median=df['Age'].median() 
df['Age'].fillna(median)
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    27.0
# 414    39.0
# 415    38.5
# 416    27.0
# 417    27.0
# Name: Age, Length: 418, dtype: float64

# %% [markdown]
# ## B)Consider titanic dataset dettect the outliers and handle the outliers

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
Q1=df['Age'].quantile(0.25)
Q3=df['Age'].quantile(0.75)
iqr=Q3-Q1 
lower_bound=Q1-1.5*iqr 
upper_bound=Q3+1.5*iqr

fare_arr=df['Age']
lower_cap=0
upper_cap=10
for i in df['Age']: 
    if i < lower_bound: 
        df['Age']=df['Agfe'].replace(i,lower_cap)
    elif i > upper_bound:
         df['Age']=df['Age'].replace(i,upper_cap)
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        3
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %% [markdown]
# ## C)Consider titanic dataset and perform data transformation operations
